# %% [markdown]
# # Gráficos

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from plotly import __version__

# %%
from plotly.offline import download_plotlyjs, plot, iplot, init_notebook_mode

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Leitura da tabela

# %%
df = pd.read_csv("..\\assets\\data\\adm_data_reduced.csv")

# %% [markdown]
# ## Info tabela

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    bool
#  7   Chance of Admit    400 non-null    float64
# dtypes: bool(1), float64(4), int64(3)
# memory usage: 22.4 KB

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65      True
# 1        324          107                  4  4.0   4.5  8.87      True
# 2        316          104                  3  3.0   3.5  8.00      True
# 3        322          110                  3  3.5   2.5  8.67      True
# 4        314          103                  2  2.0   3.0  8.21     False
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %% [markdown]
# ## Codigos

# %% [markdown]
# ### Gerais

# %%
sns.pairplot(df, hue='Chance of Admit ')

# %%
g = sns.PairGrid(df.drop('Research', axis=1))
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.lineplot)

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# ### Chance of Admit

# %%
sns.displot(df['Chance of Admit '])

# %%
sns.jointplot(data=df, x='TOEFL Score', y='Chance of Admit ')

# %%
sns.jointplot(data=df, x='CGPA', y='Chance of Admit ')

# %%
sns.jointplot(data=df, x='GRE Score', y='Chance of Admit ')

# %% [markdown]
# ### TOEFL

# %%
sns.displot(df['TOEFL Score'])

# %%
sns.jointplot(data=df, x='TOEFL Score', y='CGPA')

# %%
sns.jointplot(data=df, x='TOEFL Score', y='GRE Score')

# %% [markdown]
# ### 3D graphs

# %%
df.iplot(kind="scatter", x='TOEFL Score', y='CGPA', mode='markers')
# Out:
# <div>                            <div id="d50af764-09fd-475c-9018-7cfb0b6c6fff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['TOEFL Score','Chance of Admit ', 'GRE Score','CGPA']].iplot(kind="surface", x='Chance of Admit ')
# Out:
# <div>                            <div id="b1c5db5b-a2b1-4937-85d4-8be04c4dd85b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind="surface",x='Chance of Admit ')
# Out:
# <div>                            <div id="22aedfc5-ab9c-4b5e-8c6c-2e928d474b1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
